# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df=pd.read_csv('Match Winner.csv')
df
# Out:
#        Season   MatchDate        HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0     2000/01  2000-08-19        Charlton       Man City                  4
# 1     2000/01  2000-08-19         Chelsea       West Ham                  4
# 2     2000/01  2000-08-19        Coventry  Middlesbrough                  1
# 3     2000/01  2000-08-19           Derby    Southampton                  2
# 4     2000/01  2000-08-19           Leeds        Everton                  2
# ...       ...         ...             ...            ...                ...
# 9375  2024/25  2025-05-04       Brentford     Man United                  4
# 9376  2024/25  2025-05-04        Brighton      Newcastle                  1
# 9377  2024/25  2025-05-04        West Ham      Tottenham                  1
# 9378  2024/25  2025-05-04         Chelsea      Liverpool                  3
# 9379  2024/25  2025-05-05  Crystal Palace  Nott'm Forest                  1
#
# ...

# %%
df=df.drop(columns=['Season','MatchDate','HalfTimeHomeGoals','HalfTimeAwayGoals','HalfTimeResult'])

# %%
print(df.columns)
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FullTimeHomeGoals', 'FullTimeAwayGoals',
#        'FullTimeResult', 'HomeShots', 'AwayShots', 'HomeShotsOnTarget',
#        'AwayShotsOnTarget', 'HomeCorners', 'AwayCorners', 'HomeFouls',
#        'AwayFouls', 'HomeYellowCards', 'AwayYellowCards', 'HomeRedCards',
#        'AwayRedCards'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# HomeTeam             0
# AwayTeam             0
# FullTimeHomeGoals    0
# FullTimeAwayGoals    0
# FullTimeResult       0
# HomeShots            0
# AwayShots            0
# HomeShotsOnTarget    0
# AwayShotsOnTarget    0
# HomeCorners          0
# AwayCorners          0
# HomeFouls            0
# AwayFouls            0
# HomeYellowCards      0
# AwayYellowCards      0
# HomeRedCards         0
# AwayRedCards         0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("Match Winner.csv")
df = df[['HomeTeam', 'AwayTeam', 'FullTimeHomeGoals', 'FullTimeAwayGoals',
       'FullTimeResult', 'HomeShots', 'AwayShots', 'HomeShotsOnTarget',
       'AwayShotsOnTarget', 'HomeCorners', 'AwayCorners', 'HomeFouls',
       'AwayFouls', 'HomeYellowCards', 'AwayYellowCards', 'HomeRedCards',
       'AwayRedCards']]
df.to_csv("cleaned_dataset for match winner.csv",index=False)

# %%
import pandas as pd
file_path="cleaned_dataset for match winner.csv"
df=pd.read_csv(file_path)
categorical_cols=df.select_dtypes(include=['object']).columns
print("Categorical Columns",categorical_cols.tolist())
# Out:
# Categorical Columns ['HomeTeam', 'AwayTeam', 'FullTimeResult']

# %%
from sklearn.preprocessing import LabelEncoder
df_label=df.copy()
le=LabelEncoder()
for col in categorical_cols:
    df_label[col]=le.fit_transform(df_label[col])
print("label encoded dataset(5 rows):")
print(df_label.head())
# Out:
# label encoded dataset(5 rows):
#    HomeTeam  AwayTeam  FullTimeHomeGoals  FullTimeAwayGoals  FullTimeResult  \
# 0        12        26                  4                  0               2
# 1        13        43                  4                  2               2
# 2        14        28                  1                  3               0
# 3        16        36                  2                  2               1
# 4        22        17                  2                  0               2
#
#    HomeShots  AwayShots  HomeShotsOnTarget  AwayShotsOnTarget  HomeCorners  \
# 0         17          8                 14                  4            6
# 1         17         12                 10                  5            7
# 2          6         16                  3                  9            8
# 3          6         13                  4                  6            5
# 4         17         12                  8                  6            6
#
# ...

# %%
df_label.to_csv("label encoded dataset match winner.csv",index=False)

# %%
import pandas as pd
df=pd.read_csv("cleaned_dataset for match winner.csv")
df_onehot=pd.get_dummies(df,columns=['HomeTeam','AwayTeam','FullTimeResult'])
print("One hot encoded dataset(5 rows):")
print(df_onehot.head())
# Out:
# One hot encoded dataset(5 rows):
#    FullTimeHomeGoals  FullTimeAwayGoals  HomeShots  AwayShots  \
# 0                  4                  0         17          8
# 1                  4                  2         17         12
# 2                  1                  3          6         16
# 3                  2                  2          6         13
# 4                  2                  0         17         12
#
#    HomeShotsOnTarget  AwayShotsOnTarget  HomeCorners  AwayCorners  HomeFouls  \
# 0                 14                  4            6            6         13
# 1                 10                  5            7            7         19
# 2                  3                  9            8            4         15
# 3                  4                  6            5            8         11
# 4                  8                  6            6            4         21
#
#    AwayFouls  ...  AwayTeam_Swansea  AwayTeam_Tottenham  AwayTeam_Watford  \
# ...

# %%
df_onehot.to_csv("one hot encoded dataset match winner.csv",index=False)

# %%
df = df.drop(columns=['Season', 'MatchDate', 'HalfTimeHomeGoals', 'HalfTimeAwayGoals', 'HalfTimeResult'])

# %%
print(df)
# Out:
#             HomeTeam       AwayTeam  FullTimeHomeGoals  FullTimeAwayGoals  \
# 0           Charlton       Man City                  4                  0
# 1            Chelsea       West Ham                  4                  2
# 2           Coventry  Middlesbrough                  1                  3
# 3              Derby    Southampton                  2                  2
# 4              Leeds        Everton                  2                  0
# ...              ...            ...                ...                ...
# 9375       Brentford     Man United                  4                  3
# 9376        Brighton      Newcastle                  1                  1
# 9377        West Ham      Tottenham                  1                  1
# 9378         Chelsea      Liverpool                  3                  1
# 9379  Crystal Palace  Nott'm Forest                  1                  1
#
#      FullTimeResult  HomeShots  AwayShots  HomeShotsOnTarget  \
# ...

# %%
from IPython.display import display
display(df)
# Out:
#             HomeTeam       AwayTeam  FullTimeHomeGoals  FullTimeAwayGoals  \
# 0           Charlton       Man City                  4                  0
# 1            Chelsea       West Ham                  4                  2
# 2           Coventry  Middlesbrough                  1                  3
# 3              Derby    Southampton                  2                  2
# 4              Leeds        Everton                  2                  0
# ...              ...            ...                ...                ...
# 9375       Brentford     Man United                  4                  3
# 9376        Brighton      Newcastle                  1                  1
# 9377        West Ham      Tottenham                  1                  1
# 9378         Chelsea      Liverpool                  3                  1
# 9379  Crystal Palace  Nott'm Forest                  1                  1
#
#      FullTimeResult  HomeShots  AwayShots  HomeShotsOnTarget  \
# ...
